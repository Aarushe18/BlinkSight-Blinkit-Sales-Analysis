# %% [markdown]
#  ## **BlinkSight-Blinkit-Sales-Analysis**

# %% [markdown]
#  #### **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  #### **Import Raw Data**

# %%
df = pd.read_csv("C:/Users/Admin/Desktop/aarushe/Data Analysis Projects/Blinkit Sales Analysis/blinkit_data_raw.csv")

# %% [markdown]
#  #### **Sample Data**

# %%
df.head(20)
# Out:
#    Item Fat Content Item Identifier              Item Type  \
# 0           Regular           FDX32  Fruits and Vegetables
# 1           Low Fat           NCB42     Health and Hygiene
# 2           Regular           FDR28           Frozen Foods
# 3           Regular           FDL50                 Canned
# 4           Low Fat           DRI25            Soft Drinks
# 5           low fat           FDS52           Frozen Foods
# 6           Low Fat           NCU05     Health and Hygiene
# 7           Low Fat           NCD30              Household
# 8           Low Fat           FDW20  Fruits and Vegetables
# 9           Low Fat           FDX25                 Canned
# 10               LF           FDX21            Snack Foods
# 11          Low Fat           NCU41     Health and Hygiene
# 12          Low Fat           FDL20  Fruits and Vegetables
# 13          Low Fat           NCR54              Household
# 14          Low Fat           FDH19                   Meat
# ...

# %%
df.tail(20)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8503          Regular           FDR22            Snack Foods
# 8504          Regular           FDS09            Snack Foods
# 8505          Regular           FDS34            Snack Foods
# 8506          Regular           FDU09            Snack Foods
# 8507          Regular           FDU33            Snack Foods
# 8508          Regular           FDU57            Snack Foods
# 8509          Regular           FDU58            Snack Foods
# 8510          Regular           FDX46            Snack Foods
# 8511          Regular           FDX57            Snack Foods
# 8512          Regular           FDY33            Snack Foods
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# ...

# %% [markdown]
#  #### **Size of The Data**

# %%
print("Size of The Data", df.shape)
# Out:
# Size of The Data (8523, 12)

# %% [markdown]
#  #### **Field Information**

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
#  #### **Data Types**

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
#  #### **Data Cleaning**

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %%
df['Item Fat Content'] = df['Item Fat Content'].replace({'LF': 'Low Fat',
                                                         'low fat': 'Low Fat',
                                                         'reg': 'Regular'
                                                        })

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat']

# %% [markdown]
#  ### **BUSINESS REQUIREMENTS**

# %% [markdown]
#  ### **KPI's REQUIREMENTS**

# %%
#Total Sales
total_sales = df['Sales'].sum()

#Average Sales
avg_sales = df['Sales'].mean()

#No of Items Sold
no_of_items_sold = df['Sales'].count()

#Average Ratings
avg_ratings = df['Rating'].mean()

#Display

print(f"Total Sales: ${total_sales:,.0f}")  ## Format total_sales with $ sign, comma separators, and decimals
print(f"Average Sales: ${avg_sales:,.0f}")
print(f"No of Items Sold: {no_of_items_sold:,.0f}")
print(f"Average Ratings: {avg_ratings:,.0f}")
# Out:
# Total Sales: $1,201,681
# Average Sales: $141
# No of Items Sold: 8,523
# Average Ratings: 4

# %% [markdown]
#  ### **CHARTS REQUIREMENTS**

# %% [markdown]
#  #### **Total Sales by Fat Content**

# %%
sales_by_fat = df.groupby('Item Fat Content')['Sales'].sum()
plt.pie(sales_by_fat, labels = sales_by_fat.index,
        autopct = '%.2f%%', 
        startangle = 90)
plt.title('Sales by Fat Content')
plt.axis('equal')
plt.show()

# %% [markdown]
#  #### **Total Sales by Item Type**

# %%
# Group sales by Item Type and sort in descending order
sales_by_type = df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(sales_by_type.index, sales_by_type.values)

# Rotate x-axis labels for better readability
plt.xticks(rotation = -90)
plt.xlabel('Item Type')
plt.ylabel('Total Sales')
plt.title('Total Sales by Item Type')

# Add data labels on top of each bar
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             f'{bar.get_height():,.0f}',  # Format as comma-separated integer
             ha='center', va='bottom', fontsize=8)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
#  #### **Fat Content by Outlet for Total Sales**

# %%
# Group sales by Outlet Location Type and Item Fat Content
grouped = df.groupby(['Outlet Location Type', 'Item Fat Content'])['Sales'].sum().unstack()

# Filter to show only Regular and Low Fat
grouped = grouped[['Regular', 'Low Fat']]

# Plot grouped bar chart
ax = grouped.plot(kind = 'bar', figsize = (8, 5), title = 'Outlet Tier by Item Fat Content')

plt.xlabel('Outlet Location Tier')
plt.ylabel('Total Sales')
plt.legend(title='Item Fat Content')
plt.tight_layout()
plt.show()

# %% [markdown]
#  #### **Total Sales by Outlet Establishment**

# %%
# Group total sales by Outlet Establishment Year and sort by year
sales_by_year = df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()

# Create a line plot
plt.figure(figsize=(9, 5))
plt.plot(sales_by_year.index, sales_by_year.values, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Total Sales')
plt.title('Outlet Establishment')

# Add data labels to each point
for x, y in zip(sales_by_year.index, sales_by_year.values):
    plt.text(x, y, f'{y:,.0f}', ha = 'center', va = 'bottom', fontsize=8)

# Adjust layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
#  #### **Sales by Outlet Size**

# %%
sales_by_size = df.groupby('Outlet Size')['Sales'].sum()

plt.figure(figsize = (4,4))
plt.pie(sales_by_size, labels = sales_by_size.index, autopct = '%1.2f%%', startangle = 90)
plt.title('Outlet Size')
plt.tight_layout()
plt.show()

# %% [markdown]
#  #### **Sales by Outlet Location**

# %%
# Group total sales by Outlet Location Type and reset index for plotting
sales_by_location = df.groupby('Outlet Location Type')['Sales'].sum().reset_index()

# Sort the sales data in descending order
sales_by_location = sales_by_location.sort_values('Sales', ascending=False)

# Plotting using seaborn
plt.figure(figsize=(8, 3))  # Smaller height, wide enough for labels
ax = sns.barplot(x='Sales', y='Outlet Location Type', data=sales_by_location)

# Add title and axis labels
plt.title('Total Sales by Outlet Location Type')
plt.xlabel('Total Sales')
plt.ylabel('Outlet Location Type')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %% [markdown]
#  #### **Top 5 Best Selling Product Types**

# %%
# Group total sales by Item Type and reset index
top_products = df.groupby('Item Type')['Sales'].sum().reset_index()

# Sort and keep only the Top 5
top_products = top_products.sort_values('Sales', ascending=False).head(5)

# Create a vertical bar plot using Seaborn
plt.figure(figsize=(7, 4))  # Slightly wider to fit labels
ax = sns.barplot(x='Item Type', y='Sales', data=top_products, color='#4C72B0', width=0.6)

# Set plot title and axis labels
plt.title('Top 5 Best-Selling Product Types', fontsize=12, fontweight='bold')
plt.xlabel('Product Type', fontsize=10)
plt.ylabel('Total Sales', fontsize=10)

# Rotate x-axis labels for better fit
plt.xticks(rotation=90, fontsize=9)
plt.yticks(fontsize=9)

# Add value labels on top of bars
for bar in ax.patches:
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2,
            height,
            f'{height:,.0f}',
            ha='center', va='bottom', fontsize=8)

# Remove top/right spines for a cleaner look
sns.despine()

plt.tight_layout()
plt.show()
